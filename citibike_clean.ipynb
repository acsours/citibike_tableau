# %%
import pandas as pd

# %%
# Path to csv
file_1="resources/JC-202101-citibike-tripdata.csv"
file_2="resources/JC-202102-citibike-tripdata.csv"
file_3="resources/JC-202103-citibike-tripdata.csv"

jan_df=pd.read_csv(file_1)
jan_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1          1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2          1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3           793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4           596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
#
#    start station id start station name  start station latitude  \
# 0              3273       Manila & 1st               40.721651
# 1              3681           Grand St               40.715178
# 2              3681           Grand St               40.715178
# 3              3185          City Hall               40.717733
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.042884            3209     Brunswick St
# ...

# %%
feb_df=pd.read_csv(file_2)
feb_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           683  2021-02-01 00:08:57.2940  2021-02-01 00:20:21.2680
# 1          2850  2021-02-01 00:21:12.4910  2021-02-01 01:08:42.9560
# 2           545  2021-02-01 00:53:08.7500  2021-02-01 01:02:14.3890
# 3           473  2021-02-01 00:59:10.1110  2021-02-01 01:07:03.8480
# 4           748  2021-02-01 01:01:29.4990  2021-02-01 01:13:57.8940
#
#    start station id start station name  start station latitude  \
# 0              3483      Montgomery St               40.719420
# 1              3203      Hamilton Park               40.727596
# 2              3220  5 Corners Library               40.734961
# 3              3220  5 Corners Library               40.734961
# 4              3210     Pershing Field               40.742677
#
#    start station longitude  end station id end station name  \
# 0               -74.050990            3203    Hamilton Park
# ...

# %%
mar_df=pd.read_csv(file_3)
mar_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           369  2021-03-01 00:07:46.3700  2021-03-01 00:13:55.6430
# 1           102  2021-03-01 00:13:25.3020  2021-03-01 00:15:07.7810
# 2          2036  2021-03-01 00:16:39.7080  2021-03-01 00:50:35.8980
# 3           366  2021-03-01 00:21:44.7390  2021-03-01 00:27:51.6070
# 4           718  2021-03-01 00:22:28.1290  2021-03-01 00:34:26.3650
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3276   Marin Light Rail               40.714584
# 2              3276   Marin Light Rail               40.714584
# 3              3639         Harborside               40.719252
# 4              3483      Montgomery St               40.719420
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3639         Harborside
# ...

# %%
jan_df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# bikeid                     11624
# usertype                   11624
# birth year                 11624
# gender                     11624
# dtype: int64

# %%
jan_df=jan_df.dropna(how='any')
jan_df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# bikeid                     11624
# usertype                   11624
# birth year                 11624
# gender                     11624
# dtype: int64

# %%
jan_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
jan_df['end station name'].value_counts()
# Out:
# Grove St PATH                    1009
# Newport Pkwy                      564
# Sip Ave                           545
# Hamilton Park                     543
# Marin Light Rail                  484
# Newport PATH                      484
# Warren St                         459
# Liberty Light Rail                386
# JC Medical Center                 369
# Harborside                        353
# City Hall                         352
# Columbus Dr at Exchange Pl        323
# Washington St                     296
# Newark Ave                        276
# Morris Canal                      272
# Columbus Drive                    249
# Van Vorst Park                    248
# Jersey & 3rd                      235
# Manila & 1st                      234
# Brunswick St                      231
# Paulus Hook                       229
# Brunswick & 6th                   221
# Grand St                          212
# Jersey & 6th St                   212
# McGinley Square                   197
# ...

# %%
feb_df.count()
# Out:
# tripduration               4725
# starttime                  4725
# stoptime                   4725
# start station id           4725
# start station name         4725
# start station latitude     4725
# start station longitude    4725
# end station id             4725
# end station name           4725
# end station latitude       4725
# end station longitude      4725
# bikeid                     4725
# usertype                   4725
# birth year                 4725
# gender                     4725
# dtype: int64

# %%
feb_df.isnull().any().any()
# Out:
# False

# %%
mar_df.isnull().any().any()
# Out:
# False

# %%
feb_df.count()
# Out:
# tripduration               4725
# starttime                  4725
# stoptime                   4725
# start station id           4725
# start station name         4725
# start station latitude     4725
# start station longitude    4725
# end station id             4725
# end station name           4725
# end station latitude       4725
# end station longitude      4725
# bikeid                     4725
# usertype                   4725
# birth year                 4725
# gender                     4725
# dtype: int64

# %%
feb_df=feb_df.drop_duplicates()
feb_df.count()
# Out:
# tripduration               4725
# starttime                  4725
# stoptime                   4725
# start station id           4725
# start station name         4725
# start station latitude     4725
# start station longitude    4725
# end station id             4725
# end station name           4725
# end station latitude       4725
# end station longitude      4725
# bikeid                     4725
# usertype                   4725
# birth year                 4725
# gender                     4725
# dtype: int64

# %%
mar_df=mar_df.drop_duplicates()
mar_df.count()
# Out:
# tripduration               16843
# starttime                  16843
# stoptime                   16843
# start station id           16843
# start station name         16843
# start station latitude     16843
# start station longitude    16843
# end station id             16843
# end station name           16843
# end station latitude       16843
# end station longitude      16843
# bikeid                     16843
# usertype                   16843
# birth year                 16843
# gender                     16843
# dtype: int64

# %%
merge_df=pd.merge(jan_df, feb_df, on='start station id', how='outer')
merge_df
# Out:
#          tripduration_x               starttime_x                stoptime_x  \
# 0                   266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1                   266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 2                   266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 3                   266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 4                   266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# ...                 ...                       ...                       ...
# 1647639             990  2021-01-30 16:08:19.5370  2021-01-30 16:24:50.3170
# 1647640             990  2021-01-30 16:08:19.5370  2021-01-30 16:24:50.3170
# 1647641             990  2021-01-30 16:08:19.5370  2021-01-30 16:24:50.3170
# 1647642             990  2021-01-30 16:08:19.5370  2021-01-30 16:24:50.3170
# 1647643             990  2021-01-30 16:08:19.5370  2021-01-30 16:24:50.3170
#
# ...
